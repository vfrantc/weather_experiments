# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/weather_experiments/blob/main/run_my_model_on_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Jul 20 15:58:38 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install kornia
# !pip install kornia[x]  # to get the training API!
# !pip install thop
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 517 kB 14.2 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 117 kB 14.7 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !git clone https://github.com/vfrantc/deweather.git
# %cd deweather/TransWeather-3stage

# !cp /content/drive/MyDrive/deweather/dehaze_20ep_sigmoid.zip .
# !unzip dehaze_20ep_sigmoid.zip
# !mkdir trained
# !cp Transweather/best trained/

# !rm -rf Transweather
# !rm -rf trained_spec
# !cp /content/drive/MyDrive/deweather/despekle_20ep_sigmoid.zip .
# !unzip despekle_20ep_sigmoid.zip
# !mkdir trained_spec
# !cp Transweather/best trained_spec/
# !cp /content/drive/MyDrive/deweather2/decomp.tar .
# !cp /content/drive/MyDrive/deweather2/model_stage3_both_trained.zip .
# !unzip model_stage3_both_trained.zip
# Out:
# Cloning into 'deweather'...
# remote: Enumerating objects: 498, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 498 (delta 23), reused 22 (delta 11), pack-reused 456
# Receiving objects: 100% (498/498), 14.03 MiB | 10.15 MiB/s, done.
# Resolving deltas: 100% (282/282), done.
# /content/deweather/TransWeather-3stage
# Archive:  dehaze_20ep_sigmoid.zip
#    creating: Transweather/
#   inflating: Transweather/best
#   inflating: Transweather/latest
# Archive:  despekle_20ep_sigmoid.zip
#    creating: Transweather/
#   inflating: Transweather/latest
#   inflating: Transweather/best
# Archive:  model_stage3_both_trained.zip
# replace Transweather/best? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Transweather/best
# replace Transweather/latest? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Transweather/latest

# %%
# !cp /content/drive/MyDrive/weather_experiments/weather_test.zip .
# !unzip weather_test.zip
# !cp /content/drive/MyDrive/weather_experiments/mprnet2.zip .
# !unzip mprnet2.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: mprnet2/snowtest100k_L/winter_park_04298.jpg
#   inflating: mprnet2/snowtest100k_L/city_read_07281.jpg
#   inflating: mprnet2/snowtest100k_L/snow_animal_03405.jpg
#   inflating: mprnet2/snowtest100k_L/winter_house_05129.jpg
#   inflating: mprnet2/snowtest100k_L/city_read_10548.jpg
#   inflating: mprnet2/snowtest100k_L/winter_japan_02195.jpg
#   inflating: mprnet2/snowtest100k_L/parking_lot_06435.jpg
#   inflating: mprnet2/snowtest100k_L/winter_road_04416.jpg
#   inflating: mprnet2/snowtest100k_L/winter_japan_05638.jpg
#   inflating: mprnet2/snowtest100k_L/crossing_05745.jpg
#   inflating: mprnet2/snowtest100k_L/sidewalk winter -grayscale -gray_00782.jpg
#   inflating: mprnet2/snowtest100k_L/winter_japan_13384.jpg
#   inflating: mprnet2/snowtest100k_L/parking_lot_15981.jpg
#   inflating: mprnet2/snowtest100k_L/beautiful_smile_02058.jpg
#   inflating: mprnet2/snowtest100k_L/beautiful_smile_01639.jpg
# ...

# %%
# !ls mprnet2/fog/foggy-003.jpg
# Out:
# mprnet2/fog/foggy-003.jpg

# %%
# import cv2
# import matplotlib.pyplot as plt
# image = cv2.imread('mprnet2/real/001.png')
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# plt.imshow(image)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-15-8a894d5cc66f> in <module>()
#       2 import matplotlib.pyplot as plt
#       3 image = cv2.imread('mprnet2/real/001.png')
# ----> 4 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       5 plt.imshow(image)
#       6 plt.show()
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
# !ls mprnet2
# Out:
# fog  outdoor  rain  rain1400  rain_drop_test  sand  snow  snowtest100k_L  test1

# %%
# !ls test
# Out:
# fog	     rain	     raindroptesta.txt	sand	    snowtest100k_L.txt
# fog.txt      rain1400	     rain.txt		sand.txt    snow.txt
# outdoor      rain1400.txt    real		snow	    test1
# outdoor.txt  rain_drop_test  real.txt		Snow100K-L  test1.txt

# %%
# !rm -rf test/fog/input
# !mv mprnet2/fog test/fog/input

# !rm -rf test/real/input
# !mv mprnet2/real test/real/input

# !rm -rf test/outdoor/input
# !mv mprnet2/outdoor test/outdoor/input

# !rm -rf test/rain/input
# !mv mprnet2/rain test/rain/input

# !rm -rf test/rain1400/input
# !mv mprnet2/rain1400 test/rain1400/input

# !rm -rf test/rain_drop_test/input
# !mv mprnet2/rain_drop_test test/rain_drop_test/input

# !rm -rf test/sand/input
# !mv mprnet2/sand test/sand/input

# !rm -rf test/Snow100K-L/input
# !mv mprnet2/snowtest100k_L test/Snow100K-L/input

# !rm -rf test/test1/input
# !mv mprnet2/test1 test/test1/input

# %%
# !ls
# Out:
# base_networks.py	       mprnet2		  test_test1.py
# bla.py			       mprnet2.zip	  trained
# data.py			       perceptual.py	  trained_spec
# decomp.py		       test		  train_stage3.py
# decomp.tar		       test_me.py	  Transweather
# dehaze_20ep_sigmoid.zip        test_raindropa.py  transweather_model.py
# dehaze.py		       test_raindrop.py   utils.py
# despekle_20ep_sigmoid.zip      test_real.py	  val_data_functions.py
# model_stage3_both_trained.zip  test_snow100k.py   weather_test.zip

# %%
# !python test_me.py -exp_name=./Transweather -sset='fog'
# Out:
# Seed:	19
# cuda
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --- Testing starts! ---
# foggy-029.jpg
# foggy-095.jpg
# foggy-038.jpg
# haze-049.jpg
# foggy-035.jpg
# haze-058.jpg
# foggy-044.jpg
# foggy-040.jpg
# haze-032.jpg
# foggy-053.jpg
# foggy-057.jpg
# foggy-031.jpg
# foggy-079.jpg
# haze-080.jpg
# mist-035.jpg
# foggy-006.jpg
# foggy-048.jpg
# mist-150.jpg
# foggy-027.jpg
# haze-148.jpg
# haze-010.jpg
# haze-082.jpg
# mist-034.jpg
# mist-163.jpg
# foggy-043.jpg
# haze-036.jpg
# haze-106.jpg
# haze-016.jpg
# haze-099.jpg
# foggy-067.jpg
# haze-041.jpg
# foggy-059.jpg
# ...

# %%
# !python test_me.py -exp_name=./Transweather -sset='fog'
#!python test_me.py -exp_name=./Transweather -sset='real'
# !python test_me.py -exp_name=./Transweather -sset='outdoor'
# !python test_me.py -exp_name=./Transweather -sset='rain'
# !python test_me.py -exp_name=./Transweather -sset='rain1400'
# !python testme.py -exp_name=./Transweather -sset='raindroptesta'
# !python test_me.py -exp_name=./Transweather -sset='sand'
# !python testme.py -exp_name=./Transweather -sset='snowtest100k_L'
# !python test_me.py -exp_name=./Transweather -sset='test1'
# Out:
# Seed:	19
# cuda
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --- Testing starts! ---
# foggy-029.jpg
# foggy-095.jpg
# foggy-038.jpg
# haze-049.jpg
# foggy-035.jpg
# haze-058.jpg
# foggy-044.jpg
# foggy-040.jpg
# haze-032.jpg
# foggy-053.jpg
# foggy-057.jpg
# foggy-031.jpg
# foggy-079.jpg
# haze-080.jpg
# mist-035.jpg
# foggy-006.jpg
# foggy-048.jpg
# mist-150.jpg
# foggy-027.jpg
# haze-148.jpg
# haze-010.jpg
# haze-082.jpg
# mist-034.jpg
# mist-163.jpg
# foggy-043.jpg
# haze-036.jpg
# haze-106.jpg
# haze-016.jpg
# haze-099.jpg
# foggy-067.jpg
# haze-041.jpg
# foggy-059.jpg
# ...

# %%
# !mkdir transweather
# !cp -r results/fog/Transweather transweather/fog
# !cp -r results/real/Transweather transweather/real
# !cp -r results/outdoor/Transweather transweather/outdoor
# !cp -r results/rain/Transweather transweather/rain
# !cp -r results/rain1400/Transweather transweather/rain1400
# !cp -r results/raindroptesta/Transweather transweather/rain_drop_test
# !cp -r results/sand/Transweather transweather/sand
# !cp -r results/snowtest100k_L/Transweather transweather/snowtest100k_L
# !cp -r results/test1/Transweather transweather/test1
# Out:
# mkdir: cannot create directory ‘transweather’: File exists

# %%
# !zip -r my.zip transweather/
# !cp my.zip /content/drive/MyDrive/weather_experiments/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: transweather/snowtest100k_L/sidewalk winter -grayscale -gray_00214.jpg (deflated 0%)
#   adding: transweather/snowtest100k_L/winter_japan_15127.jpg (deflated 1%)
#   adding: transweather/snowtest100k_L/winter_japan_17947.jpg (deflated 1%)
#   adding: transweather/snowtest100k_L/winter_new_york_07164.jpg (deflated 1%)
#   adding: transweather/snowtest100k_L/school_night_07800.jpg (deflated 0%)
#   adding: transweather/snowtest100k_L/parking_lot_11966.jpg (deflated 1%)
#   adding: transweather/snowtest100k_L/beautiful_smile_01162.jpg (deflated 0%)
#   adding: transweather/snowtest100k_L/snow_animal_01881.jpg (deflated 1%)
#   adding: transweather/snowtest100k_L/winter_japan_02400.jpg (deflated 0%)
#   adding: transweather/snowtest100k_L/crossing_06690.jpg (deflated 2%)
#   adding: transweather/snowtest100k_L/parking_lot_15598.jpg (deflated 0%)
#   adding: transweather/snowtest100k_L/winter_japan_14063.jpg (deflated 1%)
# ...
