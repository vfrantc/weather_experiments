# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/weather_experiments/blob/main/convert_to_json_and_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install MMDetection

# %%
# !nvidia-smi
# Out:
# Thu Jul 28 15:20:13 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Check nvcc version
# !nvcc -V
# Check GCC version
# !gcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# install dependencies: (use cu111 because colab has CUDA 11.1)
# !pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html

# install mmcv-full thus we could use CUDA operators
# !pip install mmcv-full==1.6.0 -f https://download.openmmlab.com/mmcv/dist/cu111/torch1.9.0/index.html

# Install mmdetection
# !rm -rf mmdetection
# !git clone https://github.com/open-mmlab/mmdetection.git
# %cd mmdetection

# !pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu111/torch1.9.0/index.html
# ...
# rm: cannot remove 'mmdetection/drive/Othercomputers': Operation canceled
# rm: cannot remove 'mmdetection/drive/.file-revisions-by-id': Operation canceled
# rm: cannot remove 'mmdetection/drive/.shortcut-targets-by-id': Operation canceled
# rm: cannot remove 'mmdetection/drive/MyDrive': Operation canceled
# rm: cannot remove 'mmdetection/drive/.Trash-0': Directory not empty
# fatal: destination path 'mmdetection' already exists and is not an empty directory.
# /content/mmdetection
# ERROR: File "setup.py" or "setup.cfg" not found. Directory cannot be installed in editable mode: /content/mmdetection

# %%
import mmdet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-38ab3d8819c4> in <module>()
# ----> 1 import mmdet
#
# ModuleNotFoundError: No module named 'mmdet'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# %cd /content
# Out:
# /content

# %%
# !ls
# Out:
# mmdetection  sample_data

# %%
# !cp /content/mmdetection/drive/MyDrive/DAWN.zip .

# %%
# !unzip DAWN.zip
# Out:
# Archive:  DAWN.zip
#    creating: DAWN/
#   inflating: __MACOSX/._DAWN
#   inflating: DAWN/Rain.zip
#   inflating: __MACOSX/DAWN/._Rain.zip
#   inflating: DAWN/Sand.zip
#   inflating: __MACOSX/DAWN/._Sand.zip
#   inflating: DAWN/Snow.zip
#   inflating: __MACOSX/DAWN/._Snow.zip
#   inflating: DAWN/Fog.zip
#   inflating: __MACOSX/DAWN/._Fog.zip

# %%
# %cd DAWN/
# !unzip Fog.zip 
# !unzip Rain.zip 
# !unzip Sand.zip 
# !unzip Snow.zip
# %cd ..
# Out:
# /content/DAWN
# Archive:  Fog.zip
#    creating: Fog/
#   inflating: Fog/haze-030.jpg
#   inflating: Fog/haze-029.jpg
#   inflating: Fog/haze-028.jpg
#   inflating: Fog/haze-027.jpg
#   inflating: Fog/haze-026.jpg
#   inflating: Fog/haze-024.jpg
#   inflating: Fog/haze-023.jpg
#   inflating: Fog/haze-022.jpg
#   inflating: Fog/haze-021.jpg
#   inflating: Fog/haze-020.jpg
#   inflating: Fog/haze-019.jpg
#   inflating: Fog/haze-018.jpg
#   inflating: Fog/haze-016.jpg
#   inflating: Fog/haze-013.jpg
#   inflating: Fog/haze-012.jpg
#   inflating: Fog/haze-011.jpg
#   inflating: Fog/haze-010.jpg
#   inflating: Fog/haze-009.jpg
#   inflating: Fog/haze-007.jpg
#   inflating: Fog/haze-006.jpg
#   inflating: Fog/haze-005.jpg
#   inflating: Fog/haze-004.jpg
#   inflating: Fog/haze-003.jpg
#   inflating: Fog/haze-002.jpg
#   inflating: Fog/foggy-114.jpg
#   inflating: Fog/foggy-113.jpg
#   inflating: Fog/foggy-112.jpg
#   inflating: Fog/foggy-111.jpg
#   inflating: Fog/foggy-109.jpg
# ...

# %%
# !ls /content/DAWN/Snow
# Out:
# Snow_PASCAL_VOC     snow_storm-066.jpg	snow_storm-147.jpg  snow_storm-267.jpg
# snow_storm-001.jpg  snow_storm-067.jpg	snow_storm-149.jpg  snow_storm-269.jpg
# snow_storm-002.jpg  snow_storm-068.jpg	snow_storm-151.jpg  snow_storm-271.jpg
# snow_storm-003.jpg  snow_storm-069.jpg	snow_storm-153.jpg  snow_storm-273.jpg
# snow_storm-004.jpg  snow_storm-070.jpg	snow_storm-156.jpg  snow_storm-275.jpg
# snow_storm-005.jpg  snow_storm-071.jpg	snow_storm-158.jpg  snow_storm-279.jpg
# snow_storm-006.jpg  snow_storm-072.jpg	snow_storm-160.jpg  snow_storm-281.jpg
# snow_storm-007.jpg  snow_storm-073.jpg	snow_storm-162.jpg  snow_storm-283.jpg
# snow_storm-008.jpg  snow_storm-074.jpg	snow_storm-164.jpg  snow_storm-285.jpg
# snow_storm-009.jpg  snow_storm-075.jpg	snow_storm-166.jpg  snow_storm-289.jpg
# snow_storm-010.jpg  snow_storm-076.jpg	snow_storm-168.jpg  snow_storm-291.jpg
# snow_storm-011.jpg  snow_storm-077.jpg	snow_storm-170.jpg  snow_storm-293.jpg
# ...

# %%
import os
import sys
from glob import glob 
from tqdm.notebook import tqdm

# %%
# !mkdir -p /content/dataset/snow/Annotations
# !mkdir -p /content/dataset/snow/ImageSets/Main
# !mkdir -p /content/dataset/snow/JPEGImages
# !cp /content/DAWN/Snow/*.jpg /content/dataset/snow/JPEGImages
# !cp /content/DAWN/Snow/Snow_PASCAL_VOC/*.xml /content/dataset/snow/Annotations
with open('/content/dataset/snow/ImageSets/Main/test.txt', 'w') as fd:
  for fname in tqdm(list(glob('/content/dataset/snow/JPEGImages/*.jpg'))):
    fd.write(os.path.basename(fname).split('.')[0] + '\n')
# Out:
#   0%|          | 0/204 [00:00<?, ?it/s]

# %%
# !mkdir -p /content/dataset/rain/Annotations
# !mkdir -p /content/dataset/rain/ImageSets/Main
# !mkdir -p /content/dataset/rain/JPEGImages
# !cp /content/DAWN/Rain/*.jpg /content/dataset/rain/JPEGImages
# !cp /content/DAWN/Rain/Rain_PASCAL_VOC/*.xml /content/dataset/rain/Annotations
with open('/content/dataset/rain/ImageSets/Main/test.txt', 'w') as fd:
  for fname in tqdm(list(glob('/content/dataset/rain/JPEGImages/*.jpg'))):
    fd.write(os.path.basename(fname).split('.')[0] + '\n')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
# !mkdir -p /content/dataset/sand/Annotations
# !mkdir -p /content/dataset/sand/ImageSets/Main
# !mkdir -p /content/dataset/sand/JPEGImages
# !cp /content/DAWN/Sand/*.jpg /content/dataset/sand/JPEGImages
# !cp /content/DAWN/Sand/Sand_PASCAL_VOC/*.xml /content/dataset/sand/Annotations
with open('/content/dataset/sand/ImageSets/Main/test.txt', 'w') as fd:
  for fname in tqdm(list(glob('/content/dataset/sand/JPEGImages/*.jpg'))):
    fd.write(os.path.basename(fname).split('.')[0] + '\n')
# Out:
#   0%|          | 0/323 [00:00<?, ?it/s]

# %%
# !mkdir -p /content/dataset/fog/Annotations
# !mkdir -p /content/dataset/fog/ImageSets/Main
# !mkdir -p /content/dataset/fog/JPEGImages
# !cp /content/DAWN/Fog/*.jpg /content/dataset/fog/JPEGImages
# !cp /content/DAWN/Fog/Fog_PASCAL_VOC/foggy*.xml /content/dataset/fog/Annotations
with open('/content/dataset/fog/ImageSets/Main/test.txt', 'w') as fd:
  for fname in tqdm(list(glob('/content/dataset/fog/JPEGImages/*.jpg'))):
    fd.write(os.path.basename(fname).split('.')[0] + '\n')
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]

# %%
# !ls /content/DAWN/Rain/Rain_PASCAL_VOC/
# Out:
# rain_storm-001.xml  rain_storm-146.xml	rain_storm-385.xml  rain_storm-634.xml
# rain_storm-002.xml  rain_storm-150.xml	rain_storm-391.xml  rain_storm-638.xml
# rain_storm-003.xml  rain_storm-154.xml	rain_storm-395.xml  rain_storm-642.xml
# rain_storm-004.xml  rain_storm-158.xml	rain_storm-399.xml  rain_storm-646.xml
# rain_storm-005.xml  rain_storm-162.xml	rain_storm-403.xml  rain_storm-650.xml
# rain_storm-006.xml  rain_storm-168.xml	rain_storm-407.xml  rain_storm-654.xml
# rain_storm-007.xml  rain_storm-172.xml	rain_storm-415.xml  rain_storm-658.xml
# rain_storm-008.xml  rain_storm-176.xml	rain_storm-419.xml  rain_storm-662.xml
# rain_storm-009.xml  rain_storm-180.xml	rain_storm-423.xml  rain_storm-667.xml
# rain_storm-010.xml  rain_storm-186.xml	rain_storm-427.xml  rain_storm-676.xml
# rain_storm-011.xml  rain_storm-191.xml	rain_storm-431.xml  rain_storm-681.xml
# rain_storm-012.xml  rain_storm-195.xml	rain_storm-435.xml  rain_storm-685.xml
# ...

# %%
import numpy as np
import os.path as osp
import xml.etree.ElementTree as ET
from pprint import pprint

import mmcv
from mmdet.core import voc_classes
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-50-f50bde61f0f6> in <module>()
#       5
#       6 import mmcv
# ----> 7 from mmdet.core import voc_classes
#
# ModuleNotFoundError: No module named 'mmdet'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
categories = {1: "person",
              2: "bicycle",
              3: "car",
              4: "motorcycle",
              5: "airplane",
              6: "bus",
              7: "train",
              8: "truck",
              9: "others",
              10: "traffic light",
              11: "fire hydrant",
              13: "stop sign",
              14: "parking meter",
              15: "bench",
              16: "bird",
              17: "cat",
              18: "dog",
              19: "horse",
              20: "sheep",
              21: "cow",
              22: "elephant",
              23: "bear",
              24: "zebra",
              25: "giraffe",
              27: "backpack",
              28: "umbrella",
              31: "handbag",
              32: "tie",
              33: "suitcase",
              34: "frisbee",
              35: "skis",
              36: "snowboard",
              37: "sports ball",
              38: "kite",
              39: "baseball bat",
              40: "baseball glove",
              41: "skateboard",
              42: "surfboard",
              43: "tennis racket",
              44: "bottle",
              46: "wine glass",
              47: "cup",
              48: "fork",
              49: "knife",
              50: "spoon",
              51: "bowl",
              52: "banana",
              53: "apple",
              54: "sandwich",
              55: "orange",
              56: "broccoli",
              57: "carrot",
              58: "hot dog",
              59: "pizza",
              60: "donut",
              61: "cake",
              62: "chair",
              63: "couch",
              64: "potted plant",
              65: "bed",
              67: "dining table",
              70: "toilet",
              72: "tv",
              73: "laptop",
              74: "mouse",
              75: "remote",
              76: "keyboard",
              77: "cell phone",
              78: "microwave",
              79: "oven",
              80: "toaster",
              81: "sink",
              82: "refrigerator",
              84: "book",
              85: "clock",
              86: "vase",
              87: "scissors",
              88: "teddy bear",
              89: "hair drier",
              90: "toothbrush"}

# %%
label_ids = {name: i for i, name in categories.items()}

# %%
def parse_xml(args):
    xml_path, img_path = args # path to image and xml
    print('Processing {}'.format(xml_path))

    tree = ET.parse(xml_path) # tree for a single image
    root = tree.getroot()     # root of the tree
    size = root.find('size')  # size -> find the # rot has node with the name "size"
    old_w = int(size.find('width').text) # width of the width, get width of the image
    old_h = int(size.find('height').text) # height of the, get the height of the image
    # if old_w == 0:
    #     old_w = 1
    # if old_h == 0:
    #     old_h = 1

    # if old_h > old_w:
    #     new_w = int(old_w * 640 / old_h)
    #     new_h = 640
    # else:
    #     new_w = 640
    #     new_h = int(old_h * 640 / old_w)

    # h_ratio = new_h / old_h
    # w_ratio = new_w / old_w

    # later i will go trough all the objects available in an xml file
    # it could have several
    # and I will extract all of them
    bboxes = [] # find bounding boxes: all the bboxes available
    labels = [] # labels
    bboxes_ignore = [] # why 
    labels_ignore = []

    # go trough all the objects in the
    for obj in root.findall('object'):
        name = obj.find('name').text # name of the object
        label = label_ids[name] # label for this particular object
        difficult = int(obj.find('difficult').text) # mark if this is a difficult case
        bnd_box = obj.find('bndbox') # bndbox
        bbox = [
            int(int(bnd_box.find('xmin').text)), # xmin
            int(int(bnd_box.find('ymin').text)), # ymin
            int(int(bnd_box.find('xmax').text)), #
            int(int(bnd_box.find('ymax').text))  # ymax
        ]
        if difficult:
            bboxes_ignore.append(bbox)
            labels_ignore.append(label)
        else:
            bboxes.append(bbox)
            labels.append(label)
    if not bboxes:
        bboxes = np.zeros((0, 4))
        labels = np.zeros((0, ))
    else:
        bboxes = np.array(bboxes, ndmin=2) - 1
        labels = np.array(labels)
    if not bboxes_ignore:
        bboxes_ignore = np.zeros((0, 4))
        labels_ignore = np.zeros((0, ))
    else:
        bboxes_ignore = np.array(bboxes_ignore, ndmin=2) - 1
        labels_ignore = np.array(labels_ignore)

    # filename
    # width x height
    #
    annotation = {
        'filename': img_path,
        'width': old_w,
        'height': old_h,
        #'difficult': int(obj.find('difficult').text),
        'difficult': 0,
        'ann': {
            'bboxes': bboxes.astype(np.float32),
            'labels': labels.astype(np.int64), # thease are ides????
            'bboxes_ignore': bboxes_ignore.astype(np.float32), # this is an optional
            'labels_ignore': labels_ignore.astype(np.int64)
        }
    }
    return annotation

# %%
def cvt_annotations(devkit_path, split, out_file):
    annotations = []

    filelist = osp.join(devkit_path, f'ImageSets/Main/{split}.txt')
    if not osp.isfile(filelist):
        print(f'filelist does not exist: {filelist},',  f'skip  {split}')
        return

    img_names = mmcv.list_from_file(filelist) # all the image files
    xml_paths = [osp.join(devkit_path, f'Annotations/{img_name}.xml') for img_name in img_names]
    img_paths = [f'JPEGImages/{img_name}.jpg' for img_name in img_names]
    part_annotations = mmcv.track_progress(parse_xml, list(zip(xml_paths, img_paths)))
    annotations.extend(part_annotations)

    '''
    1: "person",
    2: "bicycle",
    3: "car",
    4: "motorbike",
    5: "airplane",
    6: "bus",
    7: "train",
    8: "truck",
    9: "boat",
    '''
    easy = {i: 0 for i in range(10)}
    difficult = {i: 0 for i in range(10)}
    for ann in annotations:
        for label in ann['ann']['labels']:
            if ann['difficult']:
                difficult[label] += 1
            else:
                easy[label] += 1

    print(f'easy: {easy}')
    print(f'difficult: {difficult}')
    # print(annotations[0])


    if out_file.endswith('json'):
        annotations = cvt_to_coco_json(annotations)
    mmcv.dump(annotations, out_file)

    return annotations

# %%
def cvt_to_coco_json(annotations):
    image_id = 0
    annotation_id = 0
    coco = dict()
    coco['images'] = []
    coco['type'] = 'instance'
    coco['categories'] = []
    coco['annotations'] = []
    image_set = set()

    def addAnnItem(annotation_id, image_id, category_id, bbox, difficult_flag):
        annotation_item = dict()
        annotation_item['segmentation'] = []

        seg = []
        # bbox[] is x1,y1,x2,y2
        # left_top
        seg.append(int(bbox[0]))
        seg.append(int(bbox[1]))
        # left_bottom
        seg.append(int(bbox[0]))
        seg.append(int(bbox[3]))
        # right_bottom
        seg.append(int(bbox[2]))
        seg.append(int(bbox[3]))
        # right_top
        seg.append(int(bbox[2]))
        seg.append(int(bbox[1]))

        annotation_item['segmentation'].append(seg)

        xywh = np.array(
            [bbox[0], bbox[1], bbox[2] - bbox[0], bbox[3] - bbox[1]])
        annotation_item['area'] = int(xywh[2] * xywh[3])
        if difficult_flag == 1:
            annotation_item['ignore'] = 0
            annotation_item['iscrowd'] = 1
        else:
            annotation_item['ignore'] = 0
            annotation_item['iscrowd'] = 0
        annotation_item['image_id'] = int(image_id)
        annotation_item['bbox'] = xywh.astype(int).tolist()
        annotation_item['category_id'] = int(category_id)
        annotation_item['id'] = int(annotation_id)
        coco['annotations'].append(annotation_item)
        return annotation_id + 1

    for category_id, name in categories.items():
        category_item = dict()
        category_item['supercategory'] = str('none')
        category_item['id'] = int(category_id)
        category_item['name'] = str(name)
        coco['categories'].append(category_item)

    for ann_dict in annotations:
        file_name = ann_dict['filename']
        ann = ann_dict['ann']
        assert file_name not in image_set
        image_item = dict()
        image_item['id'] = int(image_id)
        image_item['file_name'] = str(file_name)
        image_item['height'] = int(ann_dict['height'])
        image_item['width'] = int(ann_dict['width'])
        coco['images'].append(image_item)
        image_set.add(file_name)

        bboxes = ann['bboxes'][:, :4]
        labels = ann['labels']
        for bbox_id in range(len(bboxes)):
            bbox = bboxes[bbox_id]
            label = labels[bbox_id]
            annotation_id = addAnnItem(
                annotation_id, image_id, label, bbox, difficult_flag=0)

        bboxes_ignore = ann['bboxes_ignore'][:, :4]
        labels_ignore = ann['labels_ignore']
        for bbox_id in range(len(bboxes_ignore)):
            bbox = bboxes_ignore[bbox_id]
            label = labels_ignore[bbox_id]
            annotation_id = addAnnItem(
                annotation_id, image_id, label, bbox, difficult_flag=1)

        image_id += 1

    return coco

# %%
# !pip install python-box[all]~=6.0 --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 3.0 MB 13.2 MB/s
# ...
#      |████████████████████████████████| 109 kB 66.7 MB/s
# ...
#      |████████████████████████████████| 546 kB 63.4 MB/s
# ...

# %%
#from box import Box
#movie_box = Box({ "Robin Hood: Men in Tights": { "imdb stars": 6.7, "length": 104 } })
#movie_box.Robin_Hood_Men_in_Tights.imdb_stars

# %%
# !ls /content
# Out:
# dataset  DAWN  DAWN.zip  __MACOSX  mmdetection	out.txt  sample_data

# %%
from box import Box

def parse_args():
  args = Box({'devkit_path': '/content/dataset/fog',
              'out_dir': '/content/dataset/fog',
              'out_format': 'coco'})
  return args

# %%
args = parse_args()
devkit_path = args.devkit_path
out_dir = args.out_dir if args.out_dir else devkit_path
mmcv.mkdir_or_exist(out_dir)

out_fmt = f'.{args.out_format}'
if args.out_format == 'coco':
    out_fmt = '.json'

prefix = 'new'
dataset_name = prefix + '_test'
print(f'processing {dataset_name} ...')
cvt_annotations(devkit_path, 'test', osp.join(out_dir, dataset_name + out_fmt))
# Out:
# processing new_test ...
# [                                                  ] 0/300, elapsed: 0s, ETA:Processing /content/dataset/fog/Annotations/haze-074.xml
# [                               ] 1/300, 837.0 task/s, elapsed: 0s, ETA:     0sProcessing /content/dataset/fog/Annotations/haze-129.xml
# [                               ] 2/300, 500.3 task/s, elapsed: 0s, ETA:     1sProcessing /content/dataset/fog/Annotations/foggy-111.xml
# [                               ] 3/300, 325.4 task/s, elapsed: 0s, ETA:     1sProcessing /content/dataset/fog/Annotations/foggy-099.xml
# [                               ] 4/300, 361.1 task/s, elapsed: 0s, ETA:     1sProcessing /content/dataset/fog/Annotations/mist-024.xml
# [                               ] 5/300, 349.2 task/s, elapsed: 0s, ETA:     1sProcessing /content/dataset/fog/Annotations/mist-041.xml
# [                               ] 6/300, 356.5 task/s, elapsed: 0s, ETA:     1sProcessing /content/dataset/fog/Annotations/foggy-090.xml
# ...

# %%
# !ls /content/dataset/snow
# Out:
# Annotations  ImageSets	JPEGImages  new_test.json

# %%
# %cd /content/dataset/snow/
# Out:
# /content/dataset/snow

# %%
# %cd ..
# Out:
# /content/dataset

# %%
# !ls
# Out:
# fog  rain  sand  snow

# %%
# !zip dawn_detect.zip fog/ rain/ sand/ snow/
# !cp dawn_detect.zip /content/drive/MyDrive/weather_experiments
# Out:
#   adding: fog/ (stored 0%)
#   adding: rain/ (stored 0%)
#   adding: sand/ (stored 0%)
#   adding: snow/ (stored 0%)
# cp: cannot create regular file '/content/drive/MyDrive/weather_experiments': No such file or directory

# %%
# !cd ..

# %%
# !ls
# Out:
# dawn_detect.zip  fog  rain  sand  snow

# %%
# %cd ..
# Out:
# /content

# %%
# !ls
# Out:
# dataset  DAWN  DAWN.zip  __MACOSX  mmdetection	out.txt  sample_data

# %%
# !zip -r dawn_detect.zip dataset/
# Out:
#   adding: dataset/ (stored 0%)
#   adding: dataset/sand/ (stored 0%)
#   adding: dataset/sand/new_test.json (deflated 83%)
#   adding: dataset/sand/JPEGImages/ (stored 0%)
#   adding: dataset/sand/JPEGImages/sand_storm-324.jpg (deflated 0%)
#   adding: dataset/sand/JPEGImages/sand_storm-115.jpg (deflated 0%)
#   adding: dataset/sand/JPEGImages/dusttornado-026.jpg (deflated 1%)
#   adding: dataset/sand/JPEGImages/sand_storm-206.jpg (deflated 0%)
#   adding: dataset/sand/JPEGImages/sand_storm-009.jpg (deflated 0%)
#   adding: dataset/sand/JPEGImages/sand_storm-046.jpg (deflated 12%)
#   adding: dataset/sand/JPEGImages/sand_storm-004.jpg (deflated 14%)
#   adding: dataset/sand/JPEGImages/sand_storm-103.jpg (deflated 2%)
#   adding: dataset/sand/JPEGImages/sand_storm-225.jpg (deflated 1%)
#   adding: dataset/sand/JPEGImages/sand_storm-281.jpg (deflated 1%)
#   adding: dataset/sand/JPEGImages/sand_storm-283.jpg (deflated 1%)
# ...

# %%
# !ls
# Out:
# dataset  dawn_detect.zip  __MACOSX     out.txt
# DAWN	 DAWN.zip	  mmdetection  sample_data

# %%
# !cp dawn_detect.zip /content/mmdetection/drive/MyDrive/weather_experiments
