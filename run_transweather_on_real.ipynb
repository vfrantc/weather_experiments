# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/weather_experiments/blob/main/run_transweather_on_real.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Jul 18 22:05:02 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install kornia
# !pip install kornia[x]  # to get the training API!
# !pip install thop
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 517 kB 14.5 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 117 kB 14.4 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !git clone https://github.com/vfrantc/TransMod.git
# %cd TransMod
# Out:
# Cloning into 'TransMod'...
# remote: Enumerating objects: 446, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 446 (delta 117), reused 100 (delta 55), pack-reused 264
# Receiving objects: 100% (446/446), 11.13 MiB | 17.67 MiB/s, done.
# Resolving deltas: 100% (238/238), done.
# /content/TransMod

# %%
# !cp /content/drive/MyDrive/derain/Transweather_orig.zip .
# !unzip Transweather_orig.zip
# Out:
# Archive:  Transweather_orig.zip
#    creating: Transweather/
#   inflating: Transweather/latest
#   inflating: Transweather/best

# %%
# !cp /content/drive/MyDrive/weather_experiments/weather_test.zip .
# !unzip weather_test.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/outdoor/input/0271_0.85_0.12.jpg
#   inflating: test/outdoor/input/0248_0.8_0.08.jpg
#   inflating: test/outdoor/input/0049_0.85_0.12.jpg
#   inflating: test/outdoor/input/0213_1_0.2.jpg
#   inflating: test/outdoor/input/0304_0.9_0.08.jpg
#   inflating: test/outdoor/input/0220_0.85_0.2.jpg
#   inflating: test/outdoor/input/0066_1_0.08.jpg
#   inflating: test/outdoor/input/0296_0.95_0.12.jpg
#   inflating: test/outdoor/input/1815_1_0.2.jpg
#   inflating: test/outdoor/input/0411_0.95_0.16.jpg
#   inflating: test/outdoor/input/0102_0.85_0.12.jpg
#   inflating: test/outdoor/input/1928_0.9_0.08.jpg
#   inflating: test/outdoor/input/0194_1_0.2.jpg
#   inflating: test/outdoor/input/1986_0.9_0.08.jpg
#   inflating: test/outdoor/input/0251_0.8_0.16.jpg
#   inflating: test/outdoor/input/1953_0.8_0.2.jpg
#   inflating: test/outdoor/input/0127_0.8_0.2.jpg
#   inflating: test/outdoor/input/0003_0.8_0.2.jpg
# ...

# %%
# !python testme.py -exp_name=./Transweather -sset='fog'
# !python testme.py -exp_name=./Transweather -sset='outdoor'
# !python testme.py -exp_name=./Transweather -sset='rain'
# !python testme.py -exp_name=./Transweather -sset='rain1400'
# !python testme.py -exp_name=./Transweather -sset='raindroptesta'
# !python testme.py -exp_name=./Transweather -sset='sand'
# !python testme.py -exp_name=./Transweather -sset='snow'
# !python testme.py -exp_name=./Transweather -sset='snowtest100k_L'
# !python testme.py -exp_name=./Transweather -sset='test1'
# Out:
# Streaming output truncated to the last 5000 lines.
# city_read_17692.jpg
# winter intersection -snow_00557.jpg
# winter_new_york_00932.jpg
# winter_building_01365.jpg
# city_read_17936.jpg
# winter_park_03423.jpg
# city_read_10378.jpg
# city_read_13421.jpg
# city_read_17186.jpg
# winter_japan_16139.jpg
# sidewalk winter -grayscale -gray_06522.jpg
# city_read_15728.jpg
# winter_weather_01607.jpg
# winter_japan_13993.jpg
# parking_lot_06635.jpg
# winter_park_06370.jpg
# city_read_17904.jpg
# winter_park_02317.jpg
# winter_japan_16754.jpg
# winter_japan_15683.jpg
# winter_field_00040.jpg
# winter_japan_00457.jpg
# winter_japan_14304.jpg
# winter_building_01142.jpg
# beautiful_smile_03000.jpg
# city_read_17735.jpg
# winter_house_05335.jpg
# winter_tree_12749.jpg
# crossroad_00417.jpg
# parking_lot_14049.jpg
# parking_lot_09792.jpg
# winter_japan_01756.jpg
# crossing_00001.jpg
# beautiful_smile_03197.jpg
# winter_japan_12145.jpg
# winter_new_york_09767.jpg
# winter_japan_14919.jpg
# ...

# %%
# !ls transweather
# Out:
# fog	 rain	   rain_drop_test  sand  snowtest100k_L
# outdoor  rain1400  real		   snow  test1

# %%
# !rm -rf transweather
# !mkdir transweather

# %%
# !ls results/real/Transweather
# Out:
# 001.png  076.png  149.png  222.png  286.png  349.png  413.png  561.png	618.png
# 002.png  078.png  155.png  223.png  289.png  350.png  414.png  562.png	619.png
# 003.png  079.png  156.png  224.png  290.png  351.png  415.png  563.png	621.png
# 004.png  080.png  158.png  225.png  291.png  352.png  425.png  564.png	622.png
# 005.png  081.png  159.png  226.png  292.png  353.png  437.png  565.png	623.png
# 006.png  082.png  160.png  227.png  293.png  354.png  467.png  566.png	624.png
# 007.png  083.png  161.png  228.png  295.png  355.png  469.png  567.png	625.png
# 008.png  084.png  162.png  229.png  296.png  356.png  474.png  568.png	626.png
# 009.png  087.png  163.png  230.png  297.png  357.png  475.png  569.png	627.png
# 010.png  088.png  165.png  231.png  298.png  358.png  476.png  570.png	628.png
# 011.png  089.png  166.png  232.png  299.png  359.png  477.png  571.png	629.png
# 012.png  091.png  167.png  233.png  300.png  360.png  478.png  572.png	630.png
# ...

# %%
# !python testme.py -exp_name=./Transweather -sset='real'
# !cp -r results/real/Transweather transweather/real
# Out:
# Seed:	19
# cuda
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --- Testing starts! ---
# 363.png
# 368.png
# 242.png
# 648.png
# 114.png
# 342.png
# 253.png
# 211.png
# 156.png
# 356.png
# 650.png
# 155.png
# 053.png
# 635.png
# 559.png
# 637.png
# 223.png
# 657.png
# 046.png
# 079.png
# 216.png
# 279.png
# 282.png
# 437.png
# 180.png
# 326.png
# 413.png
# 505.png
# 205.png
# 259.png
# 411.png
# 594.png
# 611.png
# 495.png
# 084.png
# 309.png
# 387.png
# 333.png
# 208.png
# 195.png
# 398.png
# 343.png
# 570.png
# 111.png
# 658.png
# 167.png
# 149.png
# 270.png
# 579.png
# ...

# %%
# !cp -r results/fog/Transweather transweather/fog
# !cp -r results/outdoor/Transweather transweather/outdoor
# !cp -r results/rain/Transweather transweather/rain
# !cp -r results/rain1400/Transweather transweather/rain1400
# !cp -r results/raindroptesta/Transweather transweather/rain_drop_test
# !cp -r results/sand/Transweather transweather/sand
# !cp -r results/snow/Transweather transweather/snow
# !cp -r results/snowtest100k_L/Transweather transweather/snowtest100k_L
# !cp -r results/test1/Transweather transweather/test1

# %%
# !zip -r transweather.zip transweather/
# !cp transweather.zip /content/drive/MyDrive/weather_experiments/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: transweather/snowtest100k_L/winter_house_04714.jpg (deflated 1%)
#   adding: transweather/snowtest100k_L/city_read_14580.jpg (deflated 0%)
#   adding: transweather/snowtest100k_L/sidewalk winter -grayscale -gray_02489.jpg (deflated 2%)
#   adding: transweather/snowtest100k_L/city_read_20091.jpg (deflated 0%)
#   adding: transweather/snowtest100k_L/winter_park_09356.jpg (deflated 1%)
#   adding: transweather/snowtest100k_L/winter_japan_17249.jpg (deflated 0%)
#   adding: transweather/snowtest100k_L/sidewalk winter -grayscale -gray_05719.jpg (deflated 0%)
#   adding: transweather/snowtest100k_L/crossing_03350.jpg (deflated 1%)
#   adding: transweather/snowtest100k_L/winter_road_01968.jpg (deflated 2%)
#   adding: transweather/snowtest100k_L/city_read_10845.jpg (deflated 0%)
#   adding: transweather/snowtest100k_L/sidewalk winter -grayscale -gray_06804.jpg (deflated 1%)
# ...
