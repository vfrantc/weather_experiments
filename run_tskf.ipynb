# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/weather_experiments/blob/main/run_tskf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Jul 26 14:56:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !git clone https://github.com/fingerk28/Two-stage-Knowledge-For-Multiple-Adverse-Weather-Removal.git
# Out:
# Cloning into 'Two-stage-Knowledge-For-Multiple-Adverse-Weather-Removal'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 143 (delta 42), reused 61 (delta 10), pack-reused 0
# Receiving objects: 100% (143/143), 11.44 MiB | 9.84 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %%
# !cp /content/drive/MyDrive/weather_experiments/weather_test.zip .
# !unzip weather_test.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/outdoor/input/0194_1_0.2.jpg
#   inflating: test/outdoor/input/1986_0.9_0.08.jpg
#   inflating: test/outdoor/input/0251_0.8_0.16.jpg
#   inflating: test/outdoor/input/1953_0.8_0.2.jpg
#   inflating: test/outdoor/input/0127_0.8_0.2.jpg
#   inflating: test/outdoor/input/0003_0.8_0.2.jpg
#   inflating: test/outdoor/input/1861_0.85_0.2.jpg
#   inflating: test/outdoor/input/0317_0.85_0.08.jpg
#   inflating: test/outdoor/input/0269_0.95_0.2.jpg
#   inflating: test/outdoor/input/1055_0.95_0.2.jpg
#   inflating: test/outdoor/input/0267_0.9_0.16.jpg
#   inflating: test/outdoor/input/1848_0.8_0.12.jpg
#   inflating: test/outdoor/input/0082_0.85_0.16.jpg
#   inflating: test/outdoor/input/0138_0.9_0.08.jpg
#   inflating: test/outdoor/input/1724_0.95_0.2.jpg
#   inflating: test/outdoor/input/1889_0.85_0.08.jpg
#   inflating: test/outdoor/input/0302_0.9_0.16.jpg
#   inflating: test/outdoor/input/1868_1_0.08.jpg
# ...

# %%
# %cd Two-stage-Knowledge-For-Multiple-Adverse-Weather-Removal
# Out:
# /content/Two-stage-Knowledge-For-Multiple-Adverse-Weather-Removal

# %%
# !mkdir -p /content/tskf/

# %%
# !ls /content/drive/MyDrive/tskf/
# Out:
# student.pth

# %%
# !cp /content/drive/MyDrive/tskf/student.pth /content

# %%
# !ls /content/test
# Out:
# fog	     rain	     raindroptesta.txt	sand	    snowtest100k_L.txt
# fog.txt      rain1400	     rain.txt		sand.txt    snow.txt
# outdoor      rain1400.txt    real		snow	    test1
# outdoor.txt  rain_drop_test  real.txt		Snow100K-L  test1.txt

# %%
# !pip install colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !ls /content/test
# Out:
# fog	     rain	     raindroptesta.txt	sand	    snowtest100k_L.txt
# fog.txt      rain1400	     rain.txt		sand.txt    snow.txt
# outdoor      rain1400.txt    real		snow	    test1
# outdoor.txt  rain_drop_test  real.txt		Snow100K-L  test1.txt

# %%
# !mkdir -p /content/tskf/fog/
# !mkdir -p /content/tskf/outdoor/
# !mkdir -p /content/tskf/rain/
# !mkdir -p /content/tskf/rain1400/
# !mkdir -p /content/tskf/real/
# !mkdir -p /content/tskf/snow/
# !mkdir -p /content/tskf/Snow100K-L/
# !mkdir -p /content/tskf/test1/

# %%
# !python3 inference.py --dir_path /content/test/fog/input --checkpoint /content/student.pth --save_dir /content/tskf/fog
# Out:
# Using Model: models.MSBDN-RDFF.Net
# Using Dataset: utils.dataset.DatasetForInference
# ---------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# # Val data: 300
# ---------------------------------------------------------------
# Loaded checkpoint from '/content/student.pth'
# <All keys matched successfully>
# ---------------------------------------------------------------
# ==> Inference
# ...

# %%
# !python3 inference.py --dir_path /content/test/outdoor/input --checkpoint /content/student.pth --save_dir /content/tskf/outdoor
# Out:
# Using Model: models.MSBDN-RDFF.Net
# Using Dataset: utils.dataset.DatasetForInference
# ---------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# # Val data: 500
# ---------------------------------------------------------------
# Loaded checkpoint from '/content/student.pth'
# <All keys matched successfully>
# ---------------------------------------------------------------
# ==> Inference
# ...

# %%
# !python3 inference.py --dir_path /content/test/rain/input --checkpoint /content/student.pth --save_dir /content/tskf/rain
# Out:
# Using Model: models.MSBDN-RDFF.Net
# Using Dataset: utils.dataset.DatasetForInference
# ---------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# # Val data: 200
# ---------------------------------------------------------------
# Loaded checkpoint from '/content/student.pth'
# <All keys matched successfully>
# ---------------------------------------------------------------
# ==> Inference
# ...

# %%
# !python3 inference.py --dir_path /content/test/rain1400/input --checkpoint /content/student.pth --save_dir /content/tskf/rain1400
# Out:
# Using Model: models.MSBDN-RDFF.Net
# Using Dataset: utils.dataset.DatasetForInference
# ---------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# # Val data: 1400
# ---------------------------------------------------------------
# Loaded checkpoint from '/content/student.pth'
# <All keys matched successfully>
# ---------------------------------------------------------------
# ==> Inference
# ...

# %%
# !python3 inference.py --dir_path /content/test/real/input --checkpoint /content/student.pth --save_dir /content/tskf/real
# Out:
# Using Model: models.MSBDN-RDFF.Net
# Using Dataset: utils.dataset.DatasetForInference
# ---------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# # Val data: 497
# ---------------------------------------------------------------
# Loaded checkpoint from '/content/student.pth'
# <All keys matched successfully>
# ---------------------------------------------------------------
# ==> Inference
# ...

# %%
# !mkdir /content/tskf/sand

# %%
# !python3 inference.py --dir_path /content/test/sand/input --checkpoint /content/student.pth --save_dir /content/tskf/sand
# Out:
# Using Model: models.MSBDN-RDFF.Net
# Using Dataset: utils.dataset.DatasetForInference
# ---------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# # Val data: 323
# ---------------------------------------------------------------
# Loaded checkpoint from '/content/student.pth'
# <All keys matched successfully>
# ---------------------------------------------------------------
# ==> Inference
# ...

# %%
# !python3 inference.py --dir_path /content/test/snow/input --checkpoint /content/student.pth --save_dir /content/tskf/snow
# Out:
# Using Model: models.MSBDN-RDFF.Net
# Using Dataset: utils.dataset.DatasetForInference
# ---------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# # Val data: 204
# ---------------------------------------------------------------
# Loaded checkpoint from '/content/student.pth'
# <All keys matched successfully>
# ---------------------------------------------------------------
# ==> Inference
# ...

# %%
# !python3 inference.py --dir_path /content/test/Snow100K-L/input --checkpoint /content/student.pth --save_dir /content/tskf/Snow100K-L
# Out:
# Using Model: models.MSBDN-RDFF.Net
# Using Dataset: utils.dataset.DatasetForInference
# ---------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# # Val data: 16801
# ---------------------------------------------------------------
# Loaded checkpoint from '/content/student.pth'
# <All keys matched successfully>
# ---------------------------------------------------------------
# ==> Inference
# ...

# %%
# !python3 inference.py --dir_path /content/test/test1/input --checkpoint /content/student.pth --save_dir /content/tskf/test1
# Out:
# Using Model: models.MSBDN-RDFF.Net
# Using Dataset: utils.dataset.DatasetForInference
# ---------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# # Val data: 750
# ---------------------------------------------------------------
# Loaded checkpoint from '/content/student.pth'
# <All keys matched successfully>
# ---------------------------------------------------------------
# ==> Inference
# ...

# %%
# !zip -r tskf.zip /content/tskf
# !cp tskf.zip /content/drive/MyDrive/weather_experiments/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/tskf/Snow100K-L/winter_new_york_05995.jpg (deflated 1%)
#   adding: content/tskf/Snow100K-L/winter_japan_17835.jpg (deflated 4%)
#   adding: content/tskf/Snow100K-L/city_read_23298.jpg (deflated 0%)
#   adding: content/tskf/Snow100K-L/city_read_15653.jpg (deflated 0%)
#   adding: content/tskf/Snow100K-L/winter_house_05684.jpg (deflated 0%)
#   adding: content/tskf/Snow100K-L/beautiful_smile_03836.jpg (deflated 0%)
#   adding: content/tskf/Snow100K-L/winter_japan_06037.jpg (deflated 1%)
#   adding: content/tskf/Snow100K-L/winter_japan_11619.jpg (deflated 1%)
#   adding: content/tskf/Snow100K-L/winter_park_10116.jpg (deflated 0%)
#   adding: content/tskf/Snow100K-L/winter_japan_11656.jpg (deflated 1%)
#   adding: content/tskf/Snow100K-L/winter_house_03212.jpg (deflated 1%)
#   adding: content/tskf/Snow100K-L/winter_park_12473.jpg (deflated 0%)
#   adding: content/tskf/Snow100K-L/winter_japan_12116.jpg (deflated 0%)
# ...
